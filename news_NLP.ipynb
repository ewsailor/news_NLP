# %% [markdown]
# <a href="https://colab.research.google.com/github/ewsailor/news_NLP/blob/main/news_NLP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 【Task #09 作業#01】1、蒐集 聯合新聞網 文本資料

# %%
import requests
from bs4 import BeautifulSoup # BeautifulSoup 是用來解析 HTML 的套件

# 利用 requests 對 API 來源發送一個請求
response = requests.get('https://udn.com/news/breaknews/1')
soup = BeautifulSoup(response.text)

# 定義變數名稱
news = []
for link in soup.find_all('h3', class_='rounded-thumb__title')[:4]:
  news_url = link.a['href'] # 取得該新聞的連結（link.a['href']），並組成完整網址。
  news_response = requests.get('https://udn.com' + news_url)
  news_soup = BeautifulSoup(news_response.text)
  news_content = news_soup.find('div', class_='article-content__paragraph').text.strip().replace('\n', ' ')
  news.append(news_content)

print(news)
# Out:
# ['苗栗通霄拱天宮白沙屯媽祖進香活動今年36小時內從苗栗走到雲林北港朝天宮，中午12時22分媽祖鑾轎抵達朝天宮入廟，現場數十萬香燈腳及信徒歡聲雷動，拱天宮預估人潮約有近70萬人，帶著橘色帽子的香燈腳猶如橘色大軍擠滿北港大街小巷。 \r 白沙屯媽祖、山邊媽祖鑾駕今天約上午11點15分左右，停駕於北辰派出所，雲林縣長張麗善、立委張嘉郡、丁學忠及北港鎮長蕭美文，朝天宮董事長蔡咏鍀、拱天宮主委洪文華等人都在現場接駕及團拜祈福。                      \r 12時22分媽祖鑾轎抵達北港朝天宮，現場數十萬人高喊「進喔！進喔！」鑾轎三進三退衝入朝天宮，現場響起歡呼聲，入廟時間比洪文華預估的12時慢了20多分鐘。 \r 洪文華表示，白沙屯媽祖與山邊媽在進入朝天宮大殿後先安座、半小時後拜天公，預計晚上12點40分，左右進行最重要儀式「刈火」並誦讀疏文。 \r 因今年報名報名香燈腳近33萬人，疏文名冊就有1900張，大約晚間10點左右逐一誦讀名字，預估誦讀、焚燒疏文至少要2.5小時，刈火儀式後將起駕回程。 \r 朝天宮董事長蔡咏鍀指出，早上6點時多北港鎮都是人，估計近百萬人湧入北港；洪文華表示，今年參與的香燈腳進33萬人，比起往年成長很多，他預估有近70萬人擠進北港。 \r 網傳嘉義縣新港鄉已有不少民眾搭起帆布，準備媽祖回鑾時能夠迎接鑾駕，因回程時間充裕，洪文華表示，「看媽祖的意思」，不會去預設立場，等晚上刈火結束起駕，看媽祖如何安排。白沙屯媽祖、山邊媽祖鑾轎今天上午抵達北港鎮北辰派出所。記者陳雅玲／攝影白沙屯媽祖、山邊媽祖鑾轎今天中午在民眾的歡呼聲中，三退三進入廟。記者陳雅玲／攝影白沙屯媽祖鑾轎抵達北港朝天宮。圖／讀者提供白沙屯媽祖、山邊媽祖鑾轎今天中午在民眾的歡呼聲中，三退三進入廟。記者陳雅玲／攝影白沙屯媽祖徒步進香，「粉紅超跑」中午三進三退衝進北港朝天宮，線上一度高達9.7萬人朝聖。圖／取自YouTube頻道「白沙屯媽祖網路電視台」編輯推薦 🟠整理包／逾30萬香燈腳報名創紀錄！2025白沙屯媽祖「粉紅超跑」開跑 日程、儀式、禁忌一文掌握🟠直播／「急行軍」白沙屯媽祖走到哪了？跟著香燈腳線上進香     朝天宮 白沙屯媽祖                        延伸閱讀         70萬人爭睹「粉紅超跑」 北港空拍畫面震撼 9萬人看直播破紀錄  
# ...

# %% [markdown]
# 【Task #09 作業#01】2、用 pip 安裝 jieba 斷詞套件與相關工具

# %%
# 安裝 jieba 中文斷詞套件
# !pip install jieba

# 下載官方字典檔
# !wget https://raw.githubusercontent.com/fxsjy/jieba/master/extra_dict/dict.txt.big

# 載入套件與字典檔
import jieba
jieba.load_userdict("dict.txt.big")
# Out:
# ...
# --2025-05-04 05:16:30--  https://raw.githubusercontent.com/fxsjy/jieba/master/extra_dict/dict.txt.big
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.110.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 8583143 (8.2M) [application/octet-stream]
# Saving to: ‘dict.txt.big’
#
# dict.txt.big        100%[===================>]   8.18M  --.-KB/s    in 0.1s
#
# 2025-05-04 05:16:30 (82.0 MB/s) - ‘dict.txt.big’ saved [8583143/8583143]
# Building prefix dict from the default dictionary ...
# DEBUG:jieba:Building prefix dict from the default dictionary ...
# Dumping model to file cache /tmp/jieba.cache
# DEBUG:jieba:Dumping model to file cache /tmp/jieba.cache
# Loading model cost 0.903 seconds.
# DEBUG:jieba:Loading model cost 0.903 seconds.
# Prefix dict has been built successfully.
# ...

# %% [markdown]
# 【Task #09 作業#01】3、使用 jieba 對新聞文章斷詞，並製作詞頻表

# %%
import requests
from bs4 import BeautifulSoup # BeautifulSoup 是用來解析 HTML 的套件

# 利用 requests 對 API 來源發送一個請求
response = requests.get('https://udn.com/news/breaknews/1')
soup = BeautifulSoup(response.text)

# 定義變數名稱
news = []
for link in soup.find_all('h3', class_='rounded-thumb__title')[:4]:
  news_url = link.a['href'] # 取得該新聞的連結（link.a['href']），並組成完整網址。
  news_response = requests.get('https://udn.com' + news_url)
  news_soup = BeautifulSoup(news_response.text)
  news_content = news_soup.find('div', class_='article-content__paragraph').text.strip().replace('\n', ' ')
  news.append(news_content)

# 精確模式斷詞，並且將斷詞後的結果計算成每個單字的出現次數（詞頻）
# !wget https://raw.githubusercontent.com/fxsjy/jieba/master/extra_dict/dict.txt.big

import jieba
jieba.load_userdict("dict.txt.big")

word_count = {}

for d in news:
  token = list(jieba.cut(d, HMM=False)) # token = d 字串斷詞結果
  for word in token:
    if word in word_count:
      word_count[word] += 1
    else:
      word_count[word] = 1

print(word_count)
# Out:
# --2025-05-04 08:45:46--  https://raw.githubusercontent.com/fxsjy/jieba/master/extra_dict/dict.txt.big
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 8583143 (8.2M) [application/octet-stream]
# Saving to: ‘dict.txt.big’
#
# dict.txt.big        100%[===================>]   8.18M  --.-KB/s    in 0.1s
#
# 2025-05-04 08:45:47 (85.8 MB/s) - ‘dict.txt.big’ saved [8583143/8583143]
#
# ...
